# %% [markdown]
# <a href="https://colab.research.google.com/github/kimdesok/Text-classification/blob/main/Spam_Classification_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install autoviz

# %% [markdown]
# ## LSTM to Detect Spams

# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from wordcloud import WordCloud
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix

# Layers
from tensorflow.keras.layers import Bidirectional, Embedding, LSTM, Dense, Dropout

# %% [markdown]
# <h2>Loading Data</h2>

# %%
FILE_PATH = r"/content/spam.csv"
#FILE_PATH = r"/home/ubuntu/Kaggle2/Data/spam.csv"
df = pd.read_csv(FILE_PATH, encoding = 'latin-1')
df
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# 4           NaN        NaN
# ...         ...        ...
# 5567        NaN        NaN
# 5568        NaN        NaN
# 5569        NaN        NaN
# 5570        NaN        NaN
# 5571        NaN        NaN
#
# [5572 rows x 5 columns]

# %%
df = df.drop(columns=['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4']) # Removing empty columns 
df
# Out:
#         v1                                                 v2
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham              Will Ì_ b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %% [markdown]
# <h2>Visualizing Data</h2>

# %%
# Plotting a class distribution barplot
class_distribution = df['v1'].value_counts().sort_index(ascending = False)
plt.figure(figsize=(8,8))
ax = sns.countplot(x='v1', data=df, order = class_distribution.index, palette="Blues")
for i in ax.containers:
    ax.bar_label(i, label_type = 'edge', fontsize = 12)
plt.title('Target variable distribution')
plt.show()

# %%
# Plotting word cloud for ham messages
ham = " ".join(df[df['v1'] == 'ham']['v2'])
wordcloud = WordCloud(width = 900, height = 600, max_words = 200, background_color ='white').generate(ham)
plt.figure(figsize=(15,12))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title("Most Frequente Non-Spam Words")
plt.show()

# %%
# Plotting word cloud form spam messages 
spam = " ".join(df[df['v1'] == 'spam']['v2'])
wordcloud = WordCloud(width = 900, height = 600, max_words = 200, background_color ='white').generate(spam)
plt.figure(figsize=(15,12))
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.title("Most Frequente Spam Words")
plt.show()

# %%
# Printing examples of ham messages
print("Ham texts:")
print(df[df['v1'] == 'ham']['v2'].head())
# Out:
# Ham texts:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# 6    Even my brother is not like to speak with me. ...
# Name: v2, dtype: object

# %%
# Printing examples of Spam messages 
print("Spams:")
print(df[df['v1'] == 'spam']['v2'].head())
# Out:
# Spams:
# 2     Free entry in 2 a wkly comp to win FA Cup fina...
# 5     FreeMsg Hey there darling it's been 3 week's n...
# 8     WINNER!! As a valued network customer you have...
# 9     Had your mobile 11 months or more? U R entitle...
# 11    SIX chances to win CASH! From 100 to 20,000 po...
# Name: v2, dtype: object

# %% [markdown]
# <h2>Data Preprocessing</h2>

# %% [markdown]
# Data preprocessing is an essential step in any machine learning project, and it is especially important in projects containing text data.
#
# >* Data preprocessing for text data include several steps, such as cleaning, tokenizing, and vectorizing the text.
# >* Cleaning the text is the first step in the preprocessing process.
# >* This involves removing any special characters, punctuation, and stopwords, as well as converting the text to lowercase.
# >* This helps to standardize the text and make it easier for the model to process.
# >* Additionally, regular expressions (re) can be used to remove any unwanted patterns in the text such as email addresses, phone numbers or URLs.

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')

# Creating a function to clean text data
def text_cleaning(text):
    # Removing punctuation 
    text = re.sub(r'[^\w\s]', '', text)
    # Converting text to lowercase
    text = text.lower()
    # Removing digits
    text = re.sub(r'\d+','',text)
    # Removing stopwords that are common in the English language
    stop = stopwords.words('english')
    text = " ".join([word for word in text.split() if word not in stop])
    # Lemmatizing text
    lemmatizer = WordNetLemmatizer()
    text = " ".join([lemmatizer.lemmatize(word) for word in text.split()])
    # Removing white spaces
    text = text.strip()
    
    return text
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
# Splitting training and testing sets
X_train, X_test, y_train,y_test = train_test_split(df['v2'], df['v1'], test_size = 0.3, random_state = 123)

# Applying text_cleaning function
X_train = X_train.apply(text_cleaning)
X_test = X_test.apply(text_cleaning)

# %%
# Displaying text after cleansing 
X_train
# Out:
# 2156    hey cutie go wale kinda ok like hill shit stil...
# 3695                                      tirupur call da
# 4077                          gam gone outstanding inning
# 673     ditto wont worry saying anything anymore like ...
# 2659                                                   ok
#                               ...
# 5218                     accidentally brought em home box
# 4060    aight ive set free think could text blake addr...
# 1346    ok stay night xavier sleeping bag im getting t...
# 3454    need lar jus testing e phone card dunno networ...
# 3582                         sent maga money yesterday oh
# Name: v2, Length: 3900, dtype: object

# %% [markdown]
# ## Tokenization
# >* Since neural networks can only process numerical data, tokenization is done to convert text into numerical representations, while padding is applied to ensure that all input samples have the same length

# %%
# Data tokenization and padding 
max_length = max([len(i) for i in X_train])
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_train = pad_sequences(X_train, maxlen = max_length)
X_test = tokenizer.texts_to_sequences(X_test)
X_test = pad_sequences(X_test, maxlen = max_length)

# %% [markdown]
# ## Class imbalancing fixed
#
# >* Next step is to use SMOTE to address the class imbalance in the dataset. SMOTE is an oversampling technique that is commonly used to balance imbalanced datasets.<br>
#
# >* The way SMOTE works is by creating synthetic examples of the minority class by interpolating between existing minority class examples. This allows the algorithm to generate new examples of the minority class without having to collect more data. By oversampling the minority class, SMOTE helps to balance the dataset and enhance detection performance.

# %%
# Fixing class imbalance with SMOTE
smote = SMOTE(random_state = 42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# %%
# Counting values after SMOTE
y_train.value_counts()
# Out:
# ham     3368
# spam    3368
# Name: v1, dtype: int64

# %%
print(X_train[:5])
# Out:
# [[   0    0    0 ...   34 1924 1925]
#  [   0    0    0 ... 1501    2   44]
#  [   0    0    0 ...  564 1926 1927]
#  [   0    0    0 ...   21   19 1928]
#  [   0    0    0 ...    0    0   13]]

# %% [markdown]
# We now have the same ammount of spam and ham messages.

# %% [markdown]
# Next step is to use LabelEncoder to encode the target variable, since neural network models can only process numerical data.

# %%
# Encoding target variable 
encoder = LabelEncoder()
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)

# %% [markdown]
# <h2>Creating a LSTM Model</h2>

# %% [markdown]
# Long Short-Term Memory (LSTM) is a type of Recurrent Neural Network (RNN) that is particularly well-suited for handling sequential data, such as text data. It is designed to remember the context of the previous data points and use that information to process the current data point. This makes LSTM particularly useful for text classification tasks, such as spam detection, where the meaning of a word can depend on the context of the surrounding words.

# %%
# Defining model structure
model = Sequential()
# Adding embedding layer to convert input data into a dense vector representation
model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim =30, input_length = max_length))
# Adding LSTM layers 
model.add(LSTM(units=32, return_sequences = True))
model.add(LSTM(units=32))
# Adding a Dense Layer
model.add(Dense(units=32, activation = 'relu'))
model.add(Dense(units=8, activation = 'relu'))
# Adding a Dropout layer, in order to prevent overfitting
model.add(Dropout(rate=0.4))
# Adding an output Dense layer
model.add(Dense(units=1, activation = 'sigmoid'))
model

# %%
# Visualizing model structure
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 419, 30)           194880
#
#  lstm (LSTM)                 (None, 419, 32)           8064
#
#  lstm_1 (LSTM)               (None, 32)                8320
#
#  dense (Dense)               (None, 32)                1056
#
#  dense_1 (Dense)             (None, 8)                 264
#
#  dropout (Dropout)           (None, 8)                 0
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 212,593
# Trainable params: 212,593
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Defining an early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience = 24)

# %%
import tensorflow as tf
print(tf.__version__)
#print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
gpus = tf.config.experimental.list_physical_devices(device_type='GPU')
#print(gpus)
tf.debugging.set_log_device_placement(True)

#tf.config.experimental.set_visible_devices(devices=gpus[0], device_type='GPU')
#tf.config.experimental.set_memory_growth(device=gpus[0], enable=True)
# Out:
# 2.11.0

# %%
# Compiling model
opt = tf.keras.optimizers.Adam(learning_rate=0.00001)
model.compile(optimizer=opt, loss='binary_crossentropy', metrics = ['accuracy'])

# Fitting model
history = model.fit(X_train, y_train, epochs = 200, batch_size = 16, validation_split = 0.2, callbacks =[early_stopping])
# Out:
# Epoch 1/200
# 337/337 [==============================] - 37s 79ms/step - loss: 0.6906 - accuracy: 0.5917 - val_loss: 0.7040 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 337/337 [==============================] - 12s 37ms/step - loss: 0.6832 - accuracy: 0.5913 - val_loss: 0.7289 - val_accuracy: 0.0000e+00
# Epoch 3/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.6601 - accuracy: 0.5978 - val_loss: 0.8436 - val_accuracy: 0.0000e+00
# Epoch 4/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.6377 - accuracy: 0.5976 - val_loss: 0.8873 - val_accuracy: 0.0000e+00
# Epoch 5/200
# 337/337 [==============================] - 11s 31ms/step - loss: 0.6260 - accuracy: 0.5993 - val_loss: 0.8803 - val_accuracy: 0.0000e+00
# Epoch 6/200
# 337/337 [==============================] - 11s 31ms/step - loss: 0.6114 - accuracy: 0.6037 - val_loss: 0.8893 - val_accuracy: 0.0000e+00
# Epoch 7/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.5973 - accuracy: 0.6206 - val_loss: 0.8625 - val_accuracy: 0.0000e+00
# Epoch 8/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.5837 - accuracy: 0.6288 - val_loss: 0.8461 - val_accuracy: 0.0074
# Epoch 9/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.5628 - accuracy: 0.6375 - val_loss: 0.8147 - val_accuracy: 0.1180
# Epoch 10/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.5429 - accuracy: 0.6756 - val_loss: 0.7993 - val_accuracy: 0.3079
# Epoch 11/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.5253 - accuracy: 0.6939 - val_loss: 0.7878 - val_accuracy: 0.4711
# Epoch 12/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.5169 - accuracy: 0.7095 - val_loss: 0.7883 - val_accuracy: 0.5378
# Epoch 13/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.5086 - accuracy: 0.7162 - val_loss: 0.7669 - val_accuracy: 0.6617
# Epoch 14/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.4976 - accuracy: 0.7298 - val_loss: 0.7723 - val_accuracy: 0.6780
# Epoch 15/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4938 - accuracy: 0.7448 - val_loss: 0.7629 - val_accuracy: 0.7070
# Epoch 16/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.4871 - accuracy: 0.7695 - val_loss: 0.7644 - val_accuracy: 0.7114
# Epoch 17/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4790 - accuracy: 0.7890 - val_loss: 0.7631 - val_accuracy: 0.7181
# Epoch 18/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.4733 - accuracy: 0.7960 - val_loss: 0.7613 - val_accuracy: 0.7255
# Epoch 19/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4741 - accuracy: 0.7955 - val_loss: 0.7438 - val_accuracy: 0.7634
# Epoch 20/200
# 337/337 [==============================] - 10s 31ms/step - loss: 0.4747 - accuracy: 0.8018 - val_loss: 0.7357 - val_accuracy: 0.7723
# Epoch 21/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4663 - accuracy: 0.8049 - val_loss: 0.6944 - val_accuracy: 0.8435
# Epoch 22/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4660 - accuracy: 0.8062 - val_loss: 0.7200 - val_accuracy: 0.7975
# Epoch 23/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4614 - accuracy: 0.8049 - val_loss: 0.7080 - val_accuracy: 0.8131
# Epoch 24/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4573 - accuracy: 0.8062 - val_loss: 0.7141 - val_accuracy: 0.8019
# Epoch 25/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4596 - accuracy: 0.8072 - val_loss: 0.6918 - val_accuracy: 0.8294
# Epoch 26/200
# 337/337 [==============================] - 10s 31ms/step - loss: 0.4543 - accuracy: 0.8150 - val_loss: 0.7039 - val_accuracy: 0.8086
# Epoch 27/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4502 - accuracy: 0.8118 - val_loss: 0.7032 - val_accuracy: 0.8049
# Epoch 28/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4502 - accuracy: 0.8086 - val_loss: 0.6675 - val_accuracy: 0.8531
# Epoch 29/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4398 - accuracy: 0.8177 - val_loss: 0.7016 - val_accuracy: 0.8012
# Epoch 30/200
# 337/337 [==============================] - 11s 31ms/step - loss: 0.4434 - accuracy: 0.8083 - val_loss: 0.6795 - val_accuracy: 0.8197
# Epoch 31/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4420 - accuracy: 0.8140 - val_loss: 0.6752 - val_accuracy: 0.8331
# Epoch 32/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.4330 - accuracy: 0.8224 - val_loss: 0.6735 - val_accuracy: 0.8309
# Epoch 33/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4386 - accuracy: 0.8151 - val_loss: 0.6568 - val_accuracy: 0.8442
# Epoch 34/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4346 - accuracy: 0.8159 - val_loss: 0.6395 - val_accuracy: 0.8583
# Epoch 35/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4287 - accuracy: 0.8177 - val_loss: 0.6394 - val_accuracy: 0.8546
# Epoch 36/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4264 - accuracy: 0.8239 - val_loss: 0.6628 - val_accuracy: 0.8286
# Epoch 37/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.4229 - accuracy: 0.8244 - val_loss: 0.6636 - val_accuracy: 0.8205
# Epoch 38/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4302 - accuracy: 0.8215 - val_loss: 0.6211 - val_accuracy: 0.8642
# Epoch 39/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4260 - accuracy: 0.8222 - val_loss: 0.6528 - val_accuracy: 0.8227
# Epoch 40/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4187 - accuracy: 0.8265 - val_loss: 0.6232 - val_accuracy: 0.8553
# Epoch 41/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.4221 - accuracy: 0.8239 - val_loss: 0.6345 - val_accuracy: 0.8383
# Epoch 42/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4171 - accuracy: 0.8274 - val_loss: 0.5941 - val_accuracy: 0.8702
# Epoch 43/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.4140 - accuracy: 0.8280 - val_loss: 0.6107 - val_accuracy: 0.8553
# Epoch 44/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4041 - accuracy: 0.8291 - val_loss: 0.5977 - val_accuracy: 0.8628
# Epoch 45/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.4116 - accuracy: 0.8333 - val_loss: 0.6366 - val_accuracy: 0.8249
# Epoch 46/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4072 - accuracy: 0.8330 - val_loss: 0.5775 - val_accuracy: 0.8746
# Epoch 47/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4051 - accuracy: 0.8318 - val_loss: 0.6052 - val_accuracy: 0.8427
# Epoch 48/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.4005 - accuracy: 0.8400 - val_loss: 0.5958 - val_accuracy: 0.8494
# Epoch 49/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3994 - accuracy: 0.8430 - val_loss: 0.5966 - val_accuracy: 0.8464
# Epoch 50/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.4036 - accuracy: 0.8352 - val_loss: 0.5832 - val_accuracy: 0.8516
# Epoch 51/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3877 - accuracy: 0.8476 - val_loss: 0.6238 - val_accuracy: 0.8227
# Epoch 52/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3955 - accuracy: 0.8350 - val_loss: 0.5672 - val_accuracy: 0.8620
# Epoch 53/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3906 - accuracy: 0.8463 - val_loss: 0.5557 - val_accuracy: 0.8717
# Epoch 54/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3916 - accuracy: 0.8428 - val_loss: 0.5660 - val_accuracy: 0.8591
# Epoch 55/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3902 - accuracy: 0.8476 - val_loss: 0.5498 - val_accuracy: 0.8717
# Epoch 56/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3859 - accuracy: 0.8443 - val_loss: 0.5991 - val_accuracy: 0.8331
# Epoch 57/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3827 - accuracy: 0.8493 - val_loss: 0.5364 - val_accuracy: 0.8769
# Epoch 58/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.3857 - accuracy: 0.8411 - val_loss: 0.6024 - val_accuracy: 0.8249
# Epoch 59/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3860 - accuracy: 0.8448 - val_loss: 0.5539 - val_accuracy: 0.8605
# Epoch 60/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3799 - accuracy: 0.8519 - val_loss: 0.6233 - val_accuracy: 0.8086
# Epoch 61/200
# 337/337 [==============================] - 11s 32ms/step - loss: 0.3762 - accuracy: 0.8539 - val_loss: 0.5931 - val_accuracy: 0.8264
# Epoch 62/200
# 337/337 [==============================] - 11s 33ms/step - loss: 0.3750 - accuracy: 0.8502 - val_loss: 0.5873 - val_accuracy: 0.8294
# Epoch 63/200
# 337/337 [==============================] - 10s 31ms/step - loss: 0.3664 - accuracy: 0.8549 - val_loss: 0.5533 - val_accuracy: 0.8568
# Epoch 64/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3689 - accuracy: 0.8539 - val_loss: 0.5986 - val_accuracy: 0.8190
# Epoch 65/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.3649 - accuracy: 0.8593 - val_loss: 0.5316 - val_accuracy: 0.8642
# Epoch 66/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.3694 - accuracy: 0.8524 - val_loss: 0.5666 - val_accuracy: 0.8390
# Epoch 67/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3557 - accuracy: 0.8653 - val_loss: 0.5895 - val_accuracy: 0.8234
# Epoch 68/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3595 - accuracy: 0.8617 - val_loss: 0.5676 - val_accuracy: 0.8383
# Epoch 69/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.3554 - accuracy: 0.8634 - val_loss: 0.6006 - val_accuracy: 0.8108
# Epoch 70/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.3527 - accuracy: 0.8664 - val_loss: 0.5633 - val_accuracy: 0.8383
# Epoch 71/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.3547 - accuracy: 0.8690 - val_loss: 0.5839 - val_accuracy: 0.8205
# Epoch 72/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.3448 - accuracy: 0.8692 - val_loss: 0.5765 - val_accuracy: 0.8220
# Epoch 73/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.3390 - accuracy: 0.8708 - val_loss: 0.5298 - val_accuracy: 0.8509
# Epoch 74/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3461 - accuracy: 0.8714 - val_loss: 0.5474 - val_accuracy: 0.8390
# Epoch 75/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3411 - accuracy: 0.8729 - val_loss: 0.5587 - val_accuracy: 0.8331
# Epoch 76/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3364 - accuracy: 0.8729 - val_loss: 0.5534 - val_accuracy: 0.8346
# Epoch 77/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.3312 - accuracy: 0.8771 - val_loss: 0.5968 - val_accuracy: 0.8064
# Epoch 78/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.3353 - accuracy: 0.8712 - val_loss: 0.5708 - val_accuracy: 0.8212
# Epoch 79/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.3297 - accuracy: 0.8855 - val_loss: 0.5239 - val_accuracy: 0.8494
# Epoch 80/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3293 - accuracy: 0.8805 - val_loss: 0.5626 - val_accuracy: 0.8249
# Epoch 81/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3246 - accuracy: 0.8820 - val_loss: 0.5668 - val_accuracy: 0.8190
# Epoch 82/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.3217 - accuracy: 0.8816 - val_loss: 0.5310 - val_accuracy: 0.8390
# Epoch 83/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3236 - accuracy: 0.8808 - val_loss: 0.5414 - val_accuracy: 0.8309
# Epoch 84/200
# 337/337 [==============================] - 9s 27ms/step - loss: 0.3149 - accuracy: 0.8870 - val_loss: 0.5842 - val_accuracy: 0.8093
# Epoch 85/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.3096 - accuracy: 0.8970 - val_loss: 0.5465 - val_accuracy: 0.8301
# Epoch 86/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.3143 - accuracy: 0.8885 - val_loss: 0.5619 - val_accuracy: 0.8220
# Epoch 87/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.3087 - accuracy: 0.8951 - val_loss: 0.6102 - val_accuracy: 0.7960
# Epoch 88/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.3065 - accuracy: 0.8937 - val_loss: 0.5659 - val_accuracy: 0.8153
# Epoch 89/200
# 337/337 [==============================] - 10s 30ms/step - loss: 0.3112 - accuracy: 0.8912 - val_loss: 0.5986 - val_accuracy: 0.8012
# Epoch 90/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.2987 - accuracy: 0.8968 - val_loss: 0.5885 - val_accuracy: 0.8064
# Epoch 91/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.2929 - accuracy: 0.8988 - val_loss: 0.5690 - val_accuracy: 0.8175
# Epoch 92/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.2959 - accuracy: 0.8985 - val_loss: 0.6119 - val_accuracy: 0.7930
# Epoch 93/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.2940 - accuracy: 0.9005 - val_loss: 0.5799 - val_accuracy: 0.8138
# Epoch 94/200
# 337/337 [==============================] - 10s 28ms/step - loss: 0.2846 - accuracy: 0.9024 - val_loss: 0.5722 - val_accuracy: 0.8190
# Epoch 95/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.2781 - accuracy: 0.9044 - val_loss: 0.5993 - val_accuracy: 0.8019
# Epoch 96/200
# 337/337 [==============================] - 10s 31ms/step - loss: 0.2862 - accuracy: 0.9040 - val_loss: 0.5946 - val_accuracy: 0.8064
# Epoch 97/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.2819 - accuracy: 0.9053 - val_loss: 0.5959 - val_accuracy: 0.8071
# Epoch 98/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.2642 - accuracy: 0.9113 - val_loss: 0.6402 - val_accuracy: 0.7886
# Epoch 99/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.2747 - accuracy: 0.9118 - val_loss: 0.6247 - val_accuracy: 0.7975
# Epoch 100/200
# 337/337 [==============================] - 9s 28ms/step - loss: 0.2678 - accuracy: 0.9039 - val_loss: 0.5879 - val_accuracy: 0.8101
# Epoch 101/200
# 337/337 [==============================] - 9s 26ms/step - loss: 0.2725 - accuracy: 0.9050 - val_loss: 0.5768 - val_accuracy: 0.8145
# Epoch 102/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.2688 - accuracy: 0.9083 - val_loss: 0.6217 - val_accuracy: 0.7990
# Epoch 103/200
# 337/337 [==============================] - 10s 29ms/step - loss: 0.2634 - accuracy: 0.9111 - val_loss: 0.6126 - val_accuracy: 0.7990

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title(['Accuracy'])
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='lower right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title(['Loss Function'])
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train','Validation'], loc='upper right')
plt.show()

# %% [markdown]
# The model seems to be performing well on the training set but not so well on the validation set, which is an indication of overfitting.<br><br>
# We can try it out on our testing set to check its performance.

# %%
# Running model on testing set
y_pred = model.predict(X_test)
y_pred = np.round(y_pred)
# Out:
# 53/53 [==============================] - 2s 16ms/step

# %%
# Printing metric scores
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))

# Plotting a confusion matrix
cm = confusion_matrix(y_test, y_pred).astype(int)
sns.heatmap(cm, annot=True, cmap='Blues',
xticklabels=['ham', 'spam'], yticklabels=['ham', 'spam'])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()
# Out:
# Accuracy: 0.9461722488038278
# Precision: 0.7358490566037735
# Recall: 0.9069767441860465
# F1 Score: 0.8124999999999999

# %%
# Counting total values for ham messages (0) and spam messages (1) on testing set
from numpy import unique
value_counts = dict(zip(*np.unique(y_test, return_counts=True)))
print(value_counts)
# Out:
# {0: 1457, 1: 215}

# %%
# Printing accuracy on testing set
correct = np.count_nonzero(y_pred == y_test)
wrong = np.count_nonzero(y_pred != y_test)

print("The model predicted correctly",correct,"messages")
print("The model predicted incorrectly",wrong,"messages")
# Out:
# The model predicted correctly 2106974 messages
# The model predicted incorrectly 688610 messages

# %% [markdown]
# <h2>Conclusion</h2>

# %% [markdown]
# Based on the results on the testing set, it seems that the model performed quite well in terms of spam detection. The model correctly detected 270 spam messages out of 288, and correctly flagged 2,146 messages as either spam or ham, with only 83 messages being flagged incorrectly.<br><br>
#
# However, it's worth noting that the model performed poorly on the validation data, which could be an indication of overfitting. This means that the model was able to fit well to the training data but struggled to generalize to new unseen data.<br><br>
#
# To enhance performance of this model, and other similar models, several steps could be taken, such as:<br><br>
#
# - The use of techniques to prevent overfitting such as regularization, dropout, and early stopping;<br>
# - The use of more diverse data for training and validation;<br>
# - The use of more advanced architectures such as convolutional neural networks (CNNs) or transformer-based models;<br>
# - The use of pre-trained embeddings such as word2vec or GloVe, which have been trained on large amounts of text data and can provide better representation of the data;<br>
# - The use of more advanced techniques for data preprocessing such as BERT or GPT-2 for tokenization and embeddings.<br><br>
#
# It's also worth mentioning that, in this specific project, the data was imbalanced, with only 8.7% of texts  being spam. This could also have affected the model's performance on the validation set. Using techniques of data augmentation could help the model to generalize better.<br><br>
#
# In conclusion, this project has achieved good results in terms of spam detection, but the performance on validation set could be improved. To enhance the performance of this project, or other similar projects, it is recommended to use techniques to prevent overfitting, use more diverse data, use more advanced architectures, and use pre-trained embeddings.

# %% [markdown]
# Thank you for reading!<br><br>
# <i>Luís Fernando Torres</i><br><br>
# <a href="https://www.linkedin.com/in/luuisotorres/">LinkedIn</a>
